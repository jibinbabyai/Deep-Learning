# %%
pip install ultralytics

# %%
pip install tqdm  --upgrade

# %%
import os
import shutil #for file operations
import random
from tqdm.notebook import tqdm  #progress bar

# %%
# !pwd
# Out:
# /content

# %%
train_img_path = "./yolo_data/images/train/"
train_label_path = "./yolo_data/labels/train/"
val_img_path = "./yolo_data/images/val/"
val_label_path = "./yolo_data/labels/val/"
test_path= "./yolo_data/test/"

# %%
random.seed(42) #random_state=42

# %%
def train_testsplit(path,split=0.2):
  files=list(set([name[:-4] for name in os.listdir(path)]))
  print("Number of files: ",len(files))
  random.shuffle(files)
  test_size = int(len(files)*split) #66*0.2 = 13
  print("Test image size is ", test_size)
  train_size= len(files)-test_size #53
  print("Train image size is ", train_size)

  # create a directory

  os.makedirs(train_img_path,exist_ok=True)
  os.makedirs(train_label_path,exist_ok =True)
  os.makedirs(val_img_path,exist_ok=True)
  os.makedirs(val_label_path,exist_ok = True)

  # traing images
  # files copy
  # cp sourcepath destinationpath
  # copy2 sourcepath,destination

  for file in tqdm(files[:train_size]):
    shutil.copy2(path+file+".jpg",f"{train_img_path}/"+file+".jpg")
    shutil.copy2(path+file+".txt",f"{train_label_path}/"+file+".txt")
  for file in tqdm(files[train_size:]):
    shutil.copy2(path+file+".jpg",f"{val_img_path}/"+file+".jpg")
    shutil.copy2(path+file+".txt",f"{val_label_path}/"+file+".txt")

# %%
train_testsplit("/content/drive/MyDrive/Colab Notebooks/yolo/data")
# Out:
# Number of files:  66
# Test image size is  13
# Train image size is  53
#   0%|          | 0/53 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1761272122.py in <cell line: 0>()
# ----> 1 train_testsplit("/content/drive/MyDrive/Colab Notebooks/yolo/data")
#
# /tmp/ipython-input-1544690684.py in train_testsplit(path, split)
#      21
#      22   for file in tqdm(files[:train_size]):
# ---> 23     shutil.copy2(path+file+".jpg",f"{train_img_path}/"+file+".jpg")
#      24     shutil.copy2(path+file+".txt",f"{train_label_path}/"+file+".txt")
#      25   for file in tqdm(files[train_size:]):
#
# /usr/lib/python3.12/shutil.py in copy2(src, dst, follow_symlinks)
#     473                 raise
#     474
# --> 475     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     476     copystat(src, dst, follow_symlinks=follow_symlinks)
# ...

# %%
data_path = "/content/drive/MyDrive/Colab Notebooks/yolo/data"

# Check if the directory exists
if os.path.exists(data_path):
    print(f"Directory '{data_path}' exists.")
    # List the first 10 files in the directory to confirm contents
    files_in_dir = os.listdir(data_path)
    print(f"Found {len(files_in_dir)} items in the directory. First 10:")
    for i, file_name in enumerate(files_in_dir[:10]):
        print(f"  - {file_name}")
    if not any(f.endswith(('.jpg', '.txt')) for f in files_in_dir):
        print("Warning: No .jpg or .txt files found among the first 10 items. Please ensure your data is directly in this folder.")
else:
    print(f"Error: Directory '{data_path}' does NOT exist. Please double-check your path in Google Drive.")
# Out:
# Directory '/content/drive/MyDrive/Colab Notebooks/yolo/data' exists.
# Found 132 items in the directory. First 10:
#   - fre_f_145_6ty.txt
#   - fre_f_190_22d.txt
#   - we_f_105.jpg
#   - fre_f_190_22d.jpg
#   - we_f_30.jpg
#   - fre_f_60_fr.txt
#   - we_f_100.jpg
#   - rt3_f_170_6ty.jpg
#   - we_f_20.jpg
#   - fre_f_45_22d.txt

# %%
#taing image file in form of yaml

# %%
# !yolo task=detect mode=yolov8s.pt data=/content/drive/MyDrive/Colab Notebooks/yolo/dataset.yaml epochs=10 batch=8 project= /content/drive/MyDrive/Colab Notebooks/yolo/training_results name = footballplayer
