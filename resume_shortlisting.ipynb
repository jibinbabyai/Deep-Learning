# %%
import cv2,pytesseract,re

# %%
img = cv2.imread('/home/devjith/Luminar/Deep Learning/files/OCR/Resume_pic.jpg')

# %%
jd = ['nlp','opencv','python','eda','tensorflow']
jd
# Out:
# ['nlp', 'opencv', 'python', 'eda', 'tensorflow']

# %%
data = pytesseract.image_to_data(img,output_type=pytesseract.Output.DICT)

# %%
matching = []
count = 0
for i in range(len(data['text'])):
    for job in jd:
        if job in data['text'][i].lower():
            matching.append(job)


resume_score = len(set(matching)) / len(set(jd))
resume_score = resume_score *100
print(f"Your matching score is {resume_score}% ")
if resume_score >
# Out:
# Your Score is 80.0%
